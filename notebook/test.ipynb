# %%
print('Hi')
# Out:
# Hi

# %%
import pandas as pd

# %%
# !uv add pandas
# Out:
# Resolved 38 packages in 267ms
# ...
#  Downloaded numpy
#  Downloaded pandas
# Prepared 4 packages in 5.01s
# Installed 4 packages in 947ms
#  + numpy==2.3.5
#  + pandas==2.3.3
#  + pytz==2025.2
#  + tzdata==2025.2
